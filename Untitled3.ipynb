# %% [markdown]
# <a href="https://colab.research.google.com/github/ls3303123-glitch/py1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 인기 영어 강좌 빈도수

# %%
course={'TOEIC':0,'TOEFL':0,'TOEIC SPEAKING':0,'OPIC':0,'IELTS':0}

print('수강하고 싶은 강좌를 입력하세요.')
print('복수 개의 강좌를 입력하려면 콤마로 구분하세요.')

while True:
  s=input('TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료:')
  if s=='종료':
    break
  for a in s.split(','):
    if a in course:
      course[a]+=1
    else:
      print(f'{a}는 등록되지 않은 강좌입니다.')

for key, value in course.items():
  print(key,value)
# Out:
# 수강하고 싶은 강좌를 입력하세요.
# 복수 개의 강좌를 입력하려면 콤마로 구분하세요.
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료:TOEIC
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료:TOEIC SPEAKING,TOEFL
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료:TOEIC,TOEIC SPEAKING
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료:TEPS
# TEPS는 등록되지 않은 강좌입니다.
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료:종료
# TOEIC 2
# TOEFL 1
# TOEIC SPEAKING 2
# OPIC 0
# IELTS 0

# %% [markdown]
# 그래프

# %%
import matplotlib.pyplot as plt

course={'TOEIC':0,'TOEFL':0,'TOEIC SPEAKING':0,'OPIC':0,'IELTS':0}

print('수강하고 싶은 강좌를 입력하세요.')
print('복수 개의 강좌를 입력하려면 콤마로 구분하세요.')

while True:
  s=input('TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료:')
  if s=='종료':
    break
  for a in s.split(','):
    if a in course:
      course[a]+=1
    else:
      print(f'{a}는 등록되지 않은 강좌입니다.')

plt.figure(figsize=(5.5,3))
plt.bar(course.keys(),course.values(),color='g',width=0.6)
plt.title('preferred english course')
plt.xlabel('english course')
plt.ylabel('frequency')
plt.show()
# Out:
# 수강하고 싶은 강좌를 입력하세요.
# 복수 개의 강좌를 입력하려면 콤마로 구분하세요.
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료:TOEIC
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료:TOEIC SPEAKING,TOEFL
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료:TOEIC,TOEIC SPEAKING
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료:TEPS
# TEPS는 등록되지 않은 강좌입니다.
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료:종료
